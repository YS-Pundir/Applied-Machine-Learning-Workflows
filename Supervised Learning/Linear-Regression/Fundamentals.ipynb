# %%
import pandas as pd 
import numpy as np
import plotly.express as px 

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer,SimpleImputer
from sklearn.preprocessing import MinMaxScaler,StandardScaler,OneHotEncoder,LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score,recall_score,confusion_matrix,classification_report

# %%
# 1. Create a dataset of 200 students (using code from our lecture notes)
rng = np.random.default_rng(seed=42)

# Study hours between 1 and 10
study_hours = rng.uniform(low=1, high=10, size=200)

# Formula: Base score of 40 + (7.5 marks per hour) + some random noise
scores = 40 + 7.5 * study_hours + rng.normal(loc=0, scale=5, size=200)

# Let's put this into a clean Pandas DataFrame so we can view it
df_students = pd.DataFrame({
    'Study_Hours': study_hours,
    'Exam_Score': scores
})
# plotting the data
fig=px.scatter(
    df_students,
    x="Study_Hours",
    y="Exam_Score"

)
fig.show()
# diffrentiating the x , y
x=df_students[["Study_Hours"]]
y=df_students["Exam_Score"]
# Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

print(df_students.head())
# Out:
#    Study_Hours  Exam_Score
# 0     7.965604  102.958667
# 1     4.949906   75.151269
# 2     8.727381  105.429750
# 3     7.276312   93.755127
# 4     1.847596   55.544844

# %%
# Training the model 
model=LinearRegression()
model.fit(x_train,y_train)
#
print("The coefficient of the line : ",model.coef_)
print("The intercet of the line : ",model.intercept_)
# checking the acccuracy score
print(model.score(x_train,y_train))
print(model.score(x_test,y_test))
# Predicting for a new student
s=6.5
pred2=model.predict([[s]])
print(pred2)
# Out:
# The coefficient of the line :  [7.87950231]
# The intercet of the line :  37.66220092106119
# 0.9433787497328838
# 0.9278617062940906
# [88.87896591]
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
