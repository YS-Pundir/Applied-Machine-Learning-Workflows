# %%
# importing  the tools
import pandas as pd 
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.pipeline import make_pipeline

# %%
from numpy.random import default_rng

rng = default_rng(seed=99)
n = 500

study_hours        = rng.uniform(1, 10, size=n)       # daily study hours
attendance_percent = rng.uniform(40, 100, size=n)     # class attendance %
assignments_done   = rng.uniform(0, 10, size=n)       # assignments submitted (out of 10)

scores = (
    20
    + 5.5  * study_hours
    + 0.4  * attendance_percent
    + 3.0  * assignments_done
    + rng.normal(0, 8, size=n)
)

# Label: 1 = Pass, 0 = Fail
y = (scores >= 70).astype(int)
X = np.column_stack([study_hours, attendance_percent, assignments_done])
# Converting the database into the pandas dataframe 
x=pd.DataFrame(X,columns=["study_hours", "attendance_percent", "assignments_done"])
y=pd.DataFrame(y,columns=["Pass(1) or Fail(0)"])

# %%
# Spliting the data into the training and testing data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=99)
# training the model
pipeline=make_pipeline(
    MinMaxScaler(),
    LogisticRegression()
)

pipeline.fit(x_train,y_train)
print("-"*20,"Class Distribution","-"*20)
print(y.value_counts())
# Out:
# -------------------- Class Distribution --------------------
# Pass(1) or Fail(0)
# 1                     438
# 0                      62
# Name: count, dtype: int64
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
prediction=pipeline.predict(x_test)
actual=y_test
probab_pass=pipeline.predict_proba(x_test)

df_display=x_test.copy()
df_display["Actual"]=actual
df_display["Predicted"]=prediction
df_display["P(pass)"]=probab_pass[:,1]
df_display["Correct"]=df_display["Actual"]==df_display["Predicted"]
print("-"*60)
print()
print("----TABLE FOR 10 STUDENTS----")
print()
display(df_display.head(10))
# Out:
# ------------------------------------------------------------
#
# ----TABLE FOR 10 STUDENTS----
#      study_hours  attendance_percent  assignments_done  Actual  Predicted  \
# 491     7.693300           97.844798          6.995386       1          1
# 418     8.145460           65.392059          0.013780       1          1
# 251     9.945808           92.571346          7.977938       1          1
# 103     1.765306           89.163759          6.715381       1          1
# 175     8.663156           92.850135          3.352731       1          1
# 459     9.985293           69.514986          6.272427       1          1
# 402     2.592839           72.185668          6.860745       1          1
# 46      3.515666           56.623600          0.602112       0          1
# 179     4.125713           65.790476          9.502783       1          1
# 30      2.743118           53.991214          8.117927       1          1
#
#       P(pass)  Correct
# 491  0.994747     True
# 418  0.920026     True
# 251  0.998440     True
# 103  0.882557     True
# 175  0.989063     True
# 459  0.994929     True
# 402  0.874435     True
# 46   0.523935    False
# 179  0.962892     True
# 30   0.860692     True

# %%
matrix=confusion_matrix(y_test,prediction)
tn=matrix[0][0]
fp=matrix[0][1]
fn=matrix[1][0]
tp=matrix[1][1]
print("-"*60)
print()
print("\n---- BREAKDOWN ----")
print()
print(f"                   Pred MALIGNANT(0) | Pred BENIGN(1)")
print(f"Actual MALIGNANT : TN = {tn:<12} | FP = {fp} (Danger!)")
print(f"Actual BENIGN    : FN = {fn:<12} | TP = {tp}")

print()
print("---- Accuracy ----")
print("Accuracy : ",(tn+tp)/(tn+tp+fn+fp)*100,"%")
# Out:
# ------------------------------------------------------------
#
#
# ---- BREAKDOWN ----
#
#                    Pred MALIGNANT(0) | Pred BENIGN(1)
# Actual MALIGNANT : TN = 7            | FP = 11 (Danger!)
# Actual BENIGN    : FN = 1            | TP = 81
#
# ---- Accuracy ----
# Accuracy :  88.0 %

# %%
print("---- APPLING DIFFRENT THRESHOLD ----")
threshold=0.6
pred_custom=(df_display["P(pass)"]>=threshold).astype(int)
print("-"*60)

print("THRESHOLD=0.6")
print()
print("No of Pass and Fail-->")
print(pred_custom.value_counts())
print("Accuracy Acore : ",accuracy_score(y_test,pred_custom)*100,"%")
print()
print()
print("THRESHOLD=0.5")
threshold=0.5
pred_custom=(df_display["P(pass)"]>=threshold).astype(int)
print("-"*60)

print()
print("No of Pass and Fail-->")
print(pred_custom.value_counts())
print("Accuracy Acore : ",accuracy_score(y_test,pred_custom)*100,"%")
# Out:
# ---- APPLING DIFFRENT THRESHOLD ----
# ------------------------------------------------------------
# THRESHOLD=0.6
#
# No of Pass and Fail-->
# P(pass)
# 1    85
# 0    15
# Name: count, dtype: int64
# Accuracy Acore :  93.0 %
#
#
# THRESHOLD=0.5
# ------------------------------------------------------------
#
# No of Pass and Fail-->
# P(pass)
# 1    92
# 0     8
# Name: count, dtype: int64
# Accuracy Acore :  88.0 %
