# %%
# importing the tools\
import pandas as pd 
import numpy as np
import plotly.express as px

# importing the machine leanring tools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
# importing the evaluation tools
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score
print("Tools imported")
# Out:
# Tools imported

# %%
from sklearn.datasets import load_breast_cancer

# 1. Load Data & Split
cancer_data = load_breast_cancer(as_frame=True)
X_med = cancer_data.data
y_med = cancer_data.target
X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(X_med, y_med, test_size=0.2, random_state=42)

# %%
#training model with desicion tree
pipe=make_pipeline(
    MinMaxScaler(),
    DecisionTreeClassifier(max_depth=3,random_state=42)
)
pipe.fit(X_train_m,y_train_m)
prediction=pipe.predict(X_test_m)
print("----- Accuracy Scores -----")
print("The training Score : ",pipe.score(X_train_m,y_train_m)*100,"%")
print("The testing score : ",pipe.score(X_test_m,y_test_m)*100,"%")
print("----- Confusion matrix -----")
matrix=confusion_matrix(prediction,y_test_m)
print(matrix)
tn=matrix[0][0]
fp=matrix[0][1]
fn=matrix[1][0]
tp=matrix[1][1]
print()
print(f"tn : {fn} | fp : {tp}\nfn : {tn}  | tp : {fp}")
print("--------- Classification report ---------")
print(classification_report(prediction,y_test_m))
print("----- ROC-AUC -----")
# Get probabilities for the positive class
probab = pipe.predict_proba(X_test_m)[:, 1]

# Correct order: (y_true, y_score)
roc_score = roc_auc_score(y_test_m, probab)

print(f"ROC AUC Score: {roc_score:.4f}")
# Out:
# ----- Accuracy Scores -----
# The training Score :  97.8021978021978 %
# The testing score :  94.73684210526315 %
# ----- Confusion matrix -----
# [[39  2]
#  [ 4 69]]
#
# tn : 4 | fp : 69
# fn : 39  | tp : 2
# --------- Classification report ---------
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        41
#            1       0.97      0.95      0.96        73
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.95      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# ----- ROC-AUC -----
# ROC AUC Score: 0.9574

# %%
# Cheking the feature importance
feature_imp=pd.DataFrame({
    "Features":X_med.columns,
    "Imp":pipe.named_steps['decisiontreeclassifier'].feature_importances_*100
}).sort_values(by="Imp",ascending=False)

fig=px.bar(
    feature_imp,
    x="Features",
    y="Imp",
    title="The feature_imp"
)
fig.show()

# %%
#training model with desicion tree
pipe=make_pipeline(
    MinMaxScaler(),
    RandomForestClassifier(n_estimators=100,max_depth=3,random_state=42)
)
pipe.fit(X_train_m,y_train_m)
prediction=pipe.predict(X_test_m)
print("----- Accuracy Scores -----")
print("The training Score : ",pipe.score(X_train_m,y_train_m)*100,"%")
print("The testing score : ",pipe.score(X_test_m,y_test_m)*100,"%")
print("----- Confusion matrix -----")
matrix=confusion_matrix(prediction,y_test_m)
print(matrix)
tn=matrix[0][0]
fp=matrix[0][1]
fn=matrix[1][0]
tp=matrix[1][1]
print()
print(f"tn : {fn} | fp : {tp}\nfn : {tn}  | tp : {fp}")
print("--------- Classification report ---------")
print(classification_report(prediction,y_test_m))
print("----- ROC-AUC -----")
# Get probabilities for the positive class
probab = pipe.predict_proba(X_test_m)[:, 1]

# Correct order: (y_true, y_score)
roc_score = roc_auc_score(y_test_m, probab)

print(f"ROC AUC Score: {roc_score:.4f}")
# Out:
# ----- Accuracy Scores -----
# The training Score :  98.24175824175823 %
# The testing score :  96.49122807017544 %
# ----- Confusion matrix -----
# [[40  1]
#  [ 3 70]]
#
# tn : 3 | fp : 70
# fn : 40  | tp : 1
# --------- Classification report ---------
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95        41
#            1       0.99      0.96      0.97        73
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.97      0.96       114
# weighted avg       0.97      0.96      0.97       114
#
# ----- ROC-AUC -----
# ROC AUC Score: 0.9971
